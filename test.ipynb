# %%
from speciteller_wrapper import SpeciTeller

st = SpeciTeller("/home/blacfli65/Downloads/speciteller")   # slow: loads ~190MB once

sents = ["The plan was announced yesterday .",
         "Toyota will cut 350 jobs at its Tahara plant by March 2027 ."]
scores = st.predict(sents)            # pre-tokenized input
# or: st.predict_raw(raw_sentences)   # tokenizes with NLTK first
# or: st.predict(sents, return_all=True)  # combined + shallow + wordrep
# Out:
# loading brown clusters...
# done; # words:  247339
# loading word embeddings...
# done; # words:  268810

# %%
scores
# Out:
# [0.022376574463682297, 0.8312172593097578]
